# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
def Hbeta(D=np.array([]), beta=1.0):
    """
        Compute the perplexity and the P-row for a specific value of the
        precision of a Gaussian distribution.
    """

    # Compute P-row and corresponding perplexity
    P = np.exp(-D.copy() * beta)
    sumP = sum(P)
    H = np.log(sumP) + beta * np.sum(D * P) / sumP
    P = P / sumP
    return H, P


def x2p(X=np.array([]), tol=1e-5, perplexity=30.0):
    """
        Performs a binary search to get P-values in such a way that each
        conditional Gaussian has the same perplexity.
    """

    # Initialize some variables
    print("Computing pairwise distances...")
    (n, d) = X.shape
    sum_X = np.sum(np.square(X), 1)
    D = np.add(np.add(-2 * np.dot(X, X.T), sum_X).T, sum_X)
    P = np.zeros((n, n))
    beta = np.ones((n, 1))
    logU = np.log(perplexity)

    # Loop over all datapoints
    for i in range(n):

        # Print progress
        if i % 500 == 0:
            print("Computing P-values for point %d of %d..." % (i, n))

        # Compute the Gaussian kernel and entropy for the current precision
        betamin = -np.inf
        betamax = np.inf
        Di = D[i, np.concatenate((np.r_[0:i], np.r_[i+1:n]))]
        (H, thisP) = Hbeta(Di, beta[i])

        # Evaluate whether the perplexity is within tolerance
        Hdiff = H - logU
        tries = 0
        while np.abs(Hdiff) > tol and tries < 50:

            # If not, increase or decrease precision
            if Hdiff > 0:
                betamin = beta[i].copy()
                if betamax == np.inf or betamax == -np.inf:
                    beta[i] = beta[i] * 2.
                else:
                    beta[i] = (beta[i] + betamax) / 2.
            else:
                betamax = beta[i].copy()
                if betamin == np.inf or betamin == -np.inf:
                    beta[i] = beta[i] / 2.
                else:
                    beta[i] = (beta[i] + betamin) / 2.

            # Recompute the values
            (H, thisP) = Hbeta(Di, beta[i])
            Hdiff = H - logU
            tries += 1

        # Set the final row of P
        P[i, np.concatenate((np.r_[0:i], np.r_[i+1:n]))] = thisP

    # Return final P-matrix
    print("Mean value of sigma: %f" % np.mean(np.sqrt(1 / beta)))
    return P


def pca(X=np.array([]), no_dims=50):
    """
        Runs PCA on the NxD array X in order to reduce its dimensionality to
        no_dims dimensions.
    """

    print("Preprocessing the data using PCA...")
    (n, d) = X.shape
    X = X - np.tile(np.mean(X, 0), (n, 1))
    (l, M) = np.linalg.eig(np.dot(X.T, X))
    Y = np.dot(X, M[:, 0:no_dims])
    return Y

# %%
def tsne(X=np.array([]), no_dims=2, initial_dims=50, perplexity=30.0):
    """
        Runs t-SNE on the dataset in the NxD array X to reduce its
        dimensionality to no_dims dimensions. The syntaxis of the function is
        `Y = tsne.tsne(X, no_dims, perplexity), where X is an NxD NumPy array.
    """

    # Check inputs
    if isinstance(no_dims, float):
        print("Error: array X should have type float.")
        return -1
    if round(no_dims) != no_dims:
        print("Error: number of dimensions should be an integer.")
        return -1

    # Initialize variables
    X = pca(X, initial_dims).real
    (n, d) = X.shape
    max_iter = 1000
    initial_momentum = 0.5
    final_momentum = 0.8
    eta = 500
    min_gain = 0.01
    Y = np.random.randn(n, no_dims)
    dY = np.zeros((n, no_dims))
    iY = np.zeros((n, no_dims))
    gains = np.ones((n, no_dims))

    # Compute P-values
    P = x2p(X, 1e-5, perplexity)
    P = P + np.transpose(P)
    P = P / np.sum(P)
    P = P * 4.									# early exaggeration
    P = np.maximum(P, 1e-12)

    # Run iterations
    for iter in range(max_iter):

        # Compute pairwise affinities
        sum_Y = np.sum(np.square(Y), 1)
        num = -2. * np.dot(Y, Y.T)
#         num = 1. / (1. +np.add(np.add(num, sum_Y).T, sum_Y))
        num = np.exp(-1 * np.add(np.add(num, sum_Y).T, sum_Y))
        num[range(n), range(n)] = 0.
        Q = num / np.sum(num)
        Q = np.maximum(Q, 1e-12)

        # Compute gradient
        PQ = P - Q
        for i in range(n):
            dY[i, :] = np.sum(np.tile(PQ[:, i], (no_dims, 1)).T * (Y[i, :] - Y), 0)
#             dY[i, :] = np.sum(np.tile(PQ[:, i] * num[:, i], (no_dims, 1)).T * (Y[i, :] - Y), 0)

        # Perform the update
        if iter < 20:
            momentum = initial_momentum
        else:
            momentum = final_momentum
        gains = (gains + 0.2) * ((dY > 0.) != (iY > 0.)) + \
                (gains * 0.8) * ((dY > 0.) == (iY > 0.))
        gains[gains < min_gain] = min_gain
        iY = momentum * iY - eta * (gains * dY)
        Y = Y + iY
        Y = Y - np.tile(np.mean(Y, 0), (n, 1))

        # Compute current value of cost function
        if (iter + 1) % 10 == 0:
            C = np.sum(P * np.log(P / Q))
            print("Iteration %d: error is %f" % (iter + 1, C))

        # Stop lying about P-values
        if iter == 100:
            P = P / 4.

    # Return solution
    return Y

# %%
print("Run Y = tsne.tsne(X, no_dims, perplexity) to perform t-SNE on your dataset.")
print("Running example on 2,500 MNIST digits...")
X = np.loadtxt("mnist2500_X.txt")
labels = np.loadtxt("mnist2500_labels.txt")
perplexity = list(range(5, 101, 5))
for p in perplexity:
    title = 'Symmetric-SNE  Perplexity=' + str(p)
    Y = tsne(X, 2, 50, p)
    plt.scatter(Y[:, 0], Y[:, 1], 20, labels)
    plt.title(title)
    plt.show()
# Out:
# Run Y = tsne.tsne(X, no_dims, perplexity) to perform t-SNE on your dataset.
# Running example on 2,500 MNIST digits...
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 2500...
# Computing P-values for point 500 of 2500...
# Computing P-values for point 1000 of 2500...
# Computing P-values for point 1500 of 2500...
# Computing P-values for point 2000 of 2500...
# Mean value of sigma: 2.386597
# Iteration 10: error is 23.555286
# Iteration 20: error is 18.818871
# Iteration 30: error is 17.111931
# Iteration 40: error is 16.951256
# Iteration 50: error is 16.688124
# Iteration 60: error is 16.694475
# Iteration 70: error is 16.702914
# Iteration 80: error is 16.691114
# Iteration 90: error is 16.694477
# Iteration 100: error is 16.693248
# Iteration 110: error is 2.290628
# Iteration 120: error is 2.068447
# Iteration 130: error is 2.062038
# Iteration 140: error is 2.073021
# Iteration 150: error is 2.082554
# Iteration 160: error is 2.083076
# Iteration 170: error is 2.081215
# Iteration 180: error is 2.080060
# Iteration 190: error is 2.079987
# Iteration 200: error is 2.080089
# Iteration 210: error is 2.080077
# Iteration 220: error is 2.080048
# Iteration 230: error is 2.080039
# Iteration 240: error is 2.080038
# Iteration 250: error is 2.080038
# Iteration 260: error is 2.080038
# Iteration 270: error is 2.080038
# Iteration 280: error is 2.080038
# Iteration 290: error is 2.080038
# Iteration 300: error is 2.080038
# Iteration 310: error is 2.080038
# Iteration 320: error is 2.080039
# Iteration 330: error is 2.080039
# Iteration 340: error is 2.080039
# Iteration 350: error is 2.080039
# Iteration 360: error is 2.080039
# Iteration 370: error is 2.080039
# Iteration 380: error is 2.080039
# Iteration 390: error is 2.080039
# Iteration 400: error is 2.080039
# Iteration 410: error is 2.080039
# Iteration 420: error is 2.080039
# Iteration 430: error is 2.080039
# Iteration 440: error is 2.080039
# Iteration 450: error is 2.080039
# Iteration 460: error is 2.080039
# Iteration 470: error is 2.080039
# Iteration 480: error is 2.080039
t.scatter(Y[:, 0], Y[:, 1], 20, labels)
#      10     plt.title(title)
#
# <ipython-input-3-9cd4ab12c1d9> in tsne(X, no_dims, initial_dims, perplexity)
#      47
#      48         # Compute gradient
# ---> 49         PQ = P - Q
#      50         for i in range(n):
#      51             dY[i, :] = np.sum(np.tile(PQ[:, i], (no_dims, 1)).T * (Y[i, :] - Y), 0)
#
# KeyboardInterrupt:

# %%
print("Run Y = tsne.tsne(X, no_dims, perplexity) to perform t-SNE on your dataset.")
print("Running example on 2,500 MNIST digits...")
X = np.loadtxt("mnist2500_X.txt")
labels = np.loadtxt("mnist2500_labels.txt")
perplexity = list(range(10, 101, 5))
for p in perplexity:
    title = 'Symmetric-SNE  Perplexity=' + str(p)
    Y = tsne(X, 2, 50, p)
    plt.scatter(Y[:, 0], Y[:, 1], 20, labels)
    plt.title(title)
    plt.show()
# Out:
# Run Y = tsne.tsne(X, no_dims, perplexity) to perform t-SNE on your dataset.
# Running example on 2,500 MNIST digits...
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 2500...
# Computing P-values for point 500 of 2500...
# Computing P-values for point 1000 of 2500...
# Computing P-values for point 1500 of 2500...
# Computing P-values for point 2000 of 2500...
# Mean value of sigma: 2.077836
# Iteration 10: error is 25.448743
# Iteration 20: error is 20.433954
# Iteration 30: error is 18.577637
# Iteration 40: error is 18.295462
# Iteration 50: error is 18.011524
# Iteration 60: error is 17.912516
# Iteration 70: error is 17.935323
# Iteration 80: error is 17.864690
# Iteration 90: error is 17.806827
# Iteration 100: error is 17.797831
# Iteration 110: error is 2.543941
# Iteration 120: error is 2.299257
# Iteration 130: error is 2.282409
# Iteration 140: error is 2.288374
# Iteration 150: error is 2.297964
# Iteration 160: error is 2.302681
# Iteration 170: error is 2.302420
# Iteration 180: error is 2.301460
# Iteration 190: error is 2.300835
# Iteration 200: error is 2.300713
# Iteration 210: error is 2.300847
# Iteration 220: error is 2.300919
# Iteration 230: error is 2.300928
# Iteration 240: error is 2.300921
# Iteration 250: error is 2.300910
# Iteration 260: error is 2.300906
# Iteration 270: error is 2.300905
# Iteration 280: error is 2.300905
# Iteration 290: error is 2.300905
# Iteration 300: error is 2.300904
# Iteration 310: error is 2.300904
# Iteration 320: error is 2.300904
# Iteration 330: error is 2.300904
# Iteration 340: error is 2.300904
# Iteration 350: error is 2.300904
# Iteration 360: error is 2.300904
# Iteration 370: error is 2.300904
# Iteration 380: error is 2.300904
# Iteration 390: error is 2.300904
# Iteration 400: error is 2.300904
# Iteration 410: error is 2.300904
# Iteration 420: error is 2.300904
# Iteration 430: error is 2.300904
# Iteration 440: error is 2.300904
# Iteration 450: error is 2.300904
# Iteration 460: error is 2.300904
# Iteration 470: error is 2.300904
# Iteration 480: error is 2.300904
# Iteration 490: error is 2.300904
# Iteration 500: error is 2.300904
# Iteration 510: error is 2.300904
# Iteration 520: error is 2.300904
# Iteration 530: error is 2.300904
# Iteration 540: error is 2.300904
# Iteration 550: error is 2.300904
# Iteration 560: error is 2.300904
# Iteration 570: error is 2.300904
# Iteration 580: error is 2.300904
# Iteration 590: error is 2.300904
# Iteration 600: error is 2.300904
# Iteration 610: error is 2.300904
# Iteration 620: error is 2.300904
# Iteration 630: error is 2.300904
# Iteration 640: error is 2.300904
# Iteration 650: error is 2.300904
# Iteration 660: error is 2.300904
# Iteration 670: error is 2.300904
# Iteration 680: error is 2.300904
# Iteration 690: error is 2.300904
# Iteration 700: error is 2.300904
# Iteration 600: error is 1.888336
# Iteration 610: error is 1.888336
# Iteration 620: error is 1.888336
# Iteration 630: error is 1.888336
# Iteration 640: error is 1.888336
# Iteration 650: error is 1.888336
# Iteration 660: error is 1.888336
# Iteration 670: error is 1.888336
# Iteration 680: error is 1.888336
# Iteration 690: error is 1.888336
# Iteration 700: error is 1.888336
# Iteration 710: error is 1.888336
# Iteration 720: error is 1.888336
# Iteration 730: error is 1.888336
# Iteration 740: error is 1.888336
# Iteration 750: error is 1.888336
# Iteration 760: error is 1.888336
# Iteration 770: error is 1.888336
# Iteration 780: error is 1.888336
# Iteration 790: error is 1.888336
# Iteration 800: error is 1.888336
# Iteration 810: error is 1.888336
# Iteration 820: error is 1.888336
# Iteration 830: error is 1.888336
# Iteration 840: error is 1.888336
# Iteration 850: error is 1.888336
# Iteration 860: error is 1.888336
# Iteration 870: error is 1.888336
# Iteration 880: error is 1.888336
# Iteration 890: error is 1.888336
# Iteration 900: error is 1.888336
# Iteration 910: error is 1.888336
# Iteration 920: error is 1.888336
# Iteration 930: error is 1.888336
# Iteration 940: error is 1.888336
# Iteration 950: error is 1.888336
# Iteration 960: error is 1.888336
# Iteration 970: error is 1.888336
# Iteration 980: error is 1.888336
# Iteration 990: error is 1.888336
# Iteration 1000: error is 1.888336
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 2500...
# Computing P-values for point 500 of 2500...
# Computing P-values for point 1000 of 2500...
# Computing P-values for point 1500 of 2500...
# Computing P-values for point 2000 of 2500...
# Mean value of sigma: 2.769701
# Iteration 10: error is 20.790905
# Iteration 20: error is 16.720849
# Iteration 30: error is 15.975448
# Iteration 40: error is 16.061008
# Iteration 50: error is 16.008413
# Iteration 60: error is 16.019275
# Iteration 70: error is 16.011748
# Iteration 80: error is 15.995046
# Iteration 90: error is 15.873766
# Iteration 100: error is 15.915976
# Iteration 110: error is 1.958301
# Iteration 120: error is 1.894071
# Iteration 130: error is 1.910262
# Iteration 140: error is 1.917498
# Iteration 150: error is 1.909290
# Iteration 160: error is 1.906194
# Iteration 170: error is 1.906609
# Iteration 180: error is 1.907253
# Iteration 190: error is 1.907525
# Iteration 200: error is 1.907979
# Iteration 210: error is 1.908354
# Iteration 220: error is 1.908540
# Iteration 230: error is 1.908608
# Iteration 240: error is 1.908622
# Iteration 250: error is 1.908624
# Iteration 260: error is 1.908625
# Iteration 270: error is 1.908625
# Iteration 280: error is 1.908625
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-00eb67275f76> in <module>
#       6 for p in perplexity:
#       7     title = 'Symmetric-SNE  Perplexity=' + str(p)
# ----> 8     Y = tsne(X, 2, 50, p)
#       9     plt.scatter(Y[:, 0], Y[:, 1], 20, labels)
#      10     plt.title(title)
#
# <ipython-input-3-9cd4ab12c1d9> in tsne(X, no_dims, initial_dims, perplexity)
#      39         # Compute pairwise affinities
#      40         sum_Y = np.sum(np.square(Y), 1)
# ---> 41         num = -2. * np.dot(Y, Y.T)
#      42 #         num = 1. / (1. +np.add(np.add(num, sum_Y).T, sum_Y))
#      43         num = np.exp(-1 * np.add(np.add(num, sum_Y).T, sum_Y))
#
# KeyboardInterrupt:
